# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\jhanvi\jhanvi docs\AI&DS SEM1\Machine learning\Machine Learning A-Z (Codes and Datasets)\Part 2 - Regression\Section 5 - Multiple Linear Regression\Python\50_Startups.csv")

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
x = df.iloc[:, 0:4].values

# %%
x
# Out:
# array([[165349.2, 136897.8, 471784.1, 'New York'],
#        [162597.7, 151377.59, 443898.53, 'California'],
#        [153441.51, 101145.55, 407934.54, 'Florida'],
#        [144372.41, 118671.85, 383199.62, 'New York'],
#        [142107.34, 91391.77, 366168.42, 'Florida'],
#        [131876.9, 99814.71, 362861.36, 'New York'],
#        [134615.46, 147198.87, 127716.82, 'California'],
#        [130298.13, 145530.06, 323876.68, 'Florida'],
#        [120542.52, 148718.95, 311613.29, 'New York'],
#        [123334.88, 108679.17, 304981.62, 'California'],
#        [101913.08, 110594.11, 229160.95, 'Florida'],
#        [100671.96, 91790.61, 249744.55, 'California'],
#        [93863.75, 127320.38, 249839.44, 'Florida'],
#        [91992.39, 135495.07, 252664.93, 'California'],
#        [119943.24, 156547.42, 256512.92, 'Florida'],
#        [114523.61, 122616.84, 261776.23, 'New York'],
#        [78013.11, 121597.55, 264346.06, 'California'],
# ...

# %%
y = df.iloc[:, 4]

# %%
y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
labelencoder_x = LabelEncoder()
onehotencoder = OneHotEncoder()

# %%
x[:,3] = labelencoder_x.fit_transform(x[:,3])

# %%
onehot_encoder = OneHotEncoder(categories='auto', sparse=False)

# %%
transformers = [
    ('onehot', onehot_encoder, [3])
]

# %%
ct = ColumnTransformer(transformers, remainder='passthrough')

# %%
x = ct.fit_transform(x)

# %%
x
# Out:
# array([[0.0, 0.0, 1.0, 165349.2, 136897.8, 471784.1],
#        [1.0, 0.0, 0.0, 162597.7, 151377.59, 443898.53],
#        [0.0, 1.0, 0.0, 153441.51, 101145.55, 407934.54],
#        [0.0, 0.0, 1.0, 144372.41, 118671.85, 383199.62],
#        [0.0, 1.0, 0.0, 142107.34, 91391.77, 366168.42],
#        [0.0, 0.0, 1.0, 131876.9, 99814.71, 362861.36],
#        [1.0, 0.0, 0.0, 134615.46, 147198.87, 127716.82],
#        [0.0, 1.0, 0.0, 130298.13, 145530.06, 323876.68],
#        [0.0, 0.0, 1.0, 120542.52, 148718.95, 311613.29],
#        [1.0, 0.0, 0.0, 123334.88, 108679.17, 304981.62],
#        [0.0, 1.0, 0.0, 101913.08, 110594.11, 229160.95],
#        [1.0, 0.0, 0.0, 100671.96, 91790.61, 249744.55],
#        [0.0, 1.0, 0.0, 93863.75, 127320.38, 249839.44],
#        [1.0, 0.0, 0.0, 91992.39, 135495.07, 252664.93],
#        [0.0, 1.0, 0.0, 119943.24, 156547.42, 256512.92],
#        [0.0, 0.0, 1.0, 114523.61, 122616.84, 261776.23],
#        [1.0, 0.0, 0.0, 78013.11, 121597.55, 264346.06],
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
x_train
# Out:
# array([[0.0, 1.0, 0.0, 55493.95, 103057.49, 214634.81],
#        [0.0, 0.0, 1.0, 46014.02, 85047.44, 205517.64],
#        [0.0, 1.0, 0.0, 75328.87, 144135.98, 134050.07],
#        [1.0, 0.0, 0.0, 46426.07, 157693.92, 210797.67],
#        [0.0, 1.0, 0.0, 91749.16, 114175.79, 294919.57],
#        [0.0, 1.0, 0.0, 130298.13, 145530.06, 323876.68],
#        [0.0, 1.0, 0.0, 119943.24, 156547.42, 256512.92],
#        [0.0, 0.0, 1.0, 1000.23, 124153.04, 1903.93],
#        [0.0, 0.0, 1.0, 542.05, 51743.15, 0.0],
#        [0.0, 0.0, 1.0, 65605.48, 153032.06, 107138.38],
#        [0.0, 0.0, 1.0, 114523.61, 122616.84, 261776.23],
#        [0.0, 1.0, 0.0, 61994.48, 115641.28, 91131.24],
#        [1.0, 0.0, 0.0, 63408.86, 129219.61, 46085.25],
#        [1.0, 0.0, 0.0, 78013.11, 121597.55, 264346.06],
#        [1.0, 0.0, 0.0, 23640.93, 96189.63, 148001.11],
#        [1.0, 0.0, 0.0, 76253.86, 113867.3, 298664.47],
#        [0.0, 0.0, 1.0, 15505.73, 127382.3, 35534.17],
# ...

# %%
x_test
# Out:
# array([[0.0, 1.0, 0.0, 66051.52, 182645.56, 118148.2],
#        [1.0, 0.0, 0.0, 100671.96, 91790.61, 249744.55],
#        [0.0, 1.0, 0.0, 101913.08, 110594.11, 229160.95],
#        [0.0, 1.0, 0.0, 27892.92, 84710.77, 164470.71],
#        [0.0, 1.0, 0.0, 153441.51, 101145.55, 407934.54],
#        [0.0, 0.0, 1.0, 72107.6, 127864.55, 353183.81],
#        [0.0, 0.0, 1.0, 20229.59, 65947.93, 185265.1],
#        [0.0, 0.0, 1.0, 61136.38, 152701.92, 88218.23],
#        [0.0, 1.0, 0.0, 73994.56, 122782.75, 303319.26],
#        [0.0, 1.0, 0.0, 142107.34, 91391.77, 366168.42]], dtype=object)

# %%
y_train
# Out:
# 33     96778.92
# 35     96479.51
# 26    105733.54
# 34     96712.80
# 18    124266.90
# 7     155752.60
# 14    132602.65
# 45     64926.08
# 48     35673.41
# 29    101004.64
# 15    129917.04
# 30     99937.59
# 32     97427.84
# 16    126992.93
# 42     71498.49
# 20    118474.03
# 43     69758.98
# 8     152211.77
# 13    134307.35
# 25    107404.34
# 5     156991.12
# 17    125370.37
# 40     78239.91
# 49     14681.40
# 1     191792.06
# 12    141585.52
# 37     89949.14
# 24    108552.04
# 6     156122.51
# 23    108733.99
# 36     90708.19
# 21    111313.02
# 19    122776.86
# 9     149759.96
# 39     81005.76
# 46     49490.75
# 3     182901.99
# 0     192261.83
# 47     42559.73
# 44     65200.33
# Name: Profit, dtype: float64

# %%
y_test
# Out:
# 28    103282.38
# 11    144259.40
# 10    146121.95
# 41     77798.83
# 2     191050.39
# 27    105008.31
# 38     81229.06
# 31     97483.56
# 22    110352.25
# 4     166187.94
# Name: Profit, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#predicting the test set results
y_pred = regressor.predict(x_test)

# %%
y_pred
# Out:
# array([103015.20159794, 132582.27760815, 132447.73845174,  71976.09851258,
#        178537.48221057, 116161.24230168,  67851.69209677,  98791.73374686,
#        113969.43533014, 167921.06569552])

# %%
#building the optional model using backward elimination
import statsmodels.api as sm
x = np.append(arr = np.ones((50,1)).astype(int), values = x , axis = 1)

# %%
x.astype(int)
# Out:
# array([[     1,      0,      0,      1, 165349, 136897, 471784],
#        [     1,      1,      0,      0, 162597, 151377, 443898],
#        [     1,      0,      1,      0, 153441, 101145, 407934],
#        [     1,      0,      0,      1, 144372, 118671, 383199],
#        [     1,      0,      1,      0, 142107,  91391, 366168],
#        [     1,      0,      0,      1, 131876,  99814, 362861],
#        [     1,      1,      0,      0, 134615, 147198, 127716],
#        [     1,      0,      1,      0, 130298, 145530, 323876],
#        [     1,      0,      0,      1, 120542, 148718, 311613],
#        [     1,      1,      0,      0, 123334, 108679, 304981],
#        [     1,      0,      1,      0, 101913, 110594, 229160],
#        [     1,      1,      0,      0, 100671,  91790, 249744],
#        [     1,      0,      1,      0,  93863, 127320, 249839],
#        [     1,      1,      0,      0,  91992, 135495, 252664],
# ...

# %%
#fit the model with all possible pedictors
x_opt = x[:, [0,1,2,3,4,5,6]]
x_opt = x_opt.astype(float)
y = y.astype(float)
regressor_OLS = sm.OLS(endog = y,exog = x_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     169.9
# Date:                Fri, 27 Oct 2023   Prob (F-statistic):           1.34e-27
# Time:                        16:41:46   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1063.
# Df Residuals:                      44   BIC:                             1074.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.763e+04   5073.636      7.417      0.000    2.74e+04    4.79e+04
# ...

# %%
x_opt = x[:, [0,1,2,3,4,6]]
x_opt = x_opt.astype(float)
y = y.astype(float)
regressor_OLS = sm.OLS(endog = y,exog = x_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     215.8
# Date:                Fri, 27 Oct 2023   Prob (F-statistic):           9.72e-29
# Time:                        16:42:40   Log-Likelihood:                -525.53
# No. Observations:                  50   AIC:                             1061.
# Df Residuals:                      45   BIC:                             1071.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.525e+04   2100.376     16.782      0.000     3.1e+04    3.95e+04
# ...

# %%
x_opt = x[:, [0,1,2,3,4]]
x_opt = x_opt.astype(float)
y = y.astype(float)
regressor_OLS = sm.OLS(endog = y,exog = x_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.943
# Method:                 Least Squares   F-statistic:                     272.4
# Date:                Fri, 27 Oct 2023   Prob (F-statistic):           2.76e-29
# Time:                        16:46:10   Log-Likelihood:                -527.35
# No. Observations:                  50   AIC:                             1063.
# Df Residuals:                      46   BIC:                             1070.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.686e+04   1959.786     18.806      0.000    3.29e+04    4.08e+04
# ...

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Predicted vs. Actual Values")
plt.show()
